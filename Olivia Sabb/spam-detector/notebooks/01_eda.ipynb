# %%
# If running in a fresh environment, uncomment installs:
# %pip install numpy pandas scikit-learn nltk matplotlib seaborn tqdm joblib imbalanced-learn fastapi uvicorn pydantic

import sys, os, platform, sklearn, numpy as np, pandas as pd
print("Python:", platform.python_version())
print("sklearn:", sklearn.__version__)
# Out:
# Requirement already satisfied: numpy in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: pandas in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: nltk in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: matplotlib in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: seaborn in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: tqdm in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: joblib in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: imbalanced-learn in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: fastapi in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (0.121.0)
# Requirement already satisfied: uvicorn in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (0.38.0)
# Requirement already satisfied: pydantic in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (2.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from nltk) (8.3.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from fastapi) (0.49.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from fastapi) (0.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pydantic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: six>=1.5 in /home/olivia-sabb/MyProjects/spam-detector/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Python: 3.10.18
# sklearn: 1.7.2

# %%
import os
from pathlib import Path

ROOT = Path.cwd()  # adjust if your notebook is in notebooks/; e.g., ROOT = Path.cwd().parent
DATA_RAW = ROOT / "data" / "raw"
DATA_PROCESSED = ROOT / "data" / "processed"
EXPERIMENTS = ROOT / "experiments"
REPORTS = EXPERIMENTS / "reports"
CM_DIR = EXPERIMENTS / "confusion_matrices"

for d in [DATA_RAW, DATA_PROCESSED, EXPERIMENTS, REPORTS, CM_DIR]:
    d.mkdir(parents=True, exist_ok=True)

print("Root:", ROOT)
# Out:
# Root: /home/olivia-sabb/MyProjects/spam-detector/notebooks

# %%
import pandas as pd
from pathlib import Path

ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd()
DATA_RAW = ROOT / "data" / "raw"
DATA_PROCESSED = ROOT / "data" / "processed"

for d in [DATA_RAW, DATA_PROCESSED]:
    d.mkdir(parents=True, exist_ok=True)

raw_csv_path = DATA_RAW / "spam-email-dataset.csv"  # change if needed

def load_sms_spam_csv(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, encoding='latin-1')
    # Try to detect columns
    possible_label_cols = [c for c in df.columns if c.lower().startswith('spam')]
    possible_text_cols = [c for c in df.columns if c.lower() in ("text", "message") or "message" in c.lower()]
    if not possible_label_cols or not possible_text_cols:
        # For the common SMS Spam dataset on Kaggle/UCI:
        # It often has columns: v1 (spam_or_not), v2 (text)
        if "v1" in df.columns and "v2" in df.columns:
            df = df[["v1", "v2"]]
            df.columns = ["spam_or_not", "text"]
        elif "text" in df.columns and "spam" in df.columns:
            df = df[["text", "spam"]]
            df.columns = ["text", "spam_or_not"]
        else:
            raise ValueError(f"Could not find spam/text columns in {path}. Columns: {df.columns.tolist()}")
    else:
        df = df[[possible_label_cols[0], possible_text_cols[0]]]
        df.columns = ["spam_or_not", "text"]
    df = df.dropna(subset=["text"])
    df["spam_or_not"] = df["spam_or_not"].astype(int)
    return df

df_raw = load_sms_spam_csv(raw_csv_path)
df_raw.head()
# Out:
#    spam_or_not                                               text
# 0            1  Subject: naturally irresistible your corporate...
# 1            1  Subject: the stock trading gunslinger  fanny i...
# 2            1  Subject: unbelievable new homes made easy  im ...
# 3            1  Subject: 4 color printing special  request add...
# 4            1  Subject: do not have money , get software cds ...

# %%
import re

def basic_clean(text: str) -> str:
    text = text.lower()
    text = re.sub(r"http\S+|www\.\S+", " URL ", text)
    text = re.sub(r"\d+", " NUM ", text)
    text = re.sub(r"[^a-zA-Z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df = df_raw.copy()
df["text"] = df["text"].astype(str).apply(basic_clean)
df.head(), df["spam_or_not"].value_counts()
# Out:
# (   spam_or_not                                               text
#  0            1  subject naturally irresistible your corporate ...
#  1            1  subject the stock trading gunslinger fanny is ...
#  2            1  subject unbelievable new homes made easy im wa...
#  3            1  subject NUM color printing special request add...
#  4            1  subject do not have money get software cds fro...,
#  spam_or_not
#  0    4360
#  1    1368
#  Name: count, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["spam_or_not"], test_size=0.2, random_state=42, stratify=df["spam_or_not"]
)

pd.DataFrame({"text": X_train, "spam_or_not": y_train}).to_csv(DATA_PROCESSED / "train.csv", index=False)
pd.DataFrame({"text": X_test, "spam_or_not": y_test}).to_csv(DATA_PROCESSED / "test.csv", index=False)

len(X_train), len(X_test)
# Out:
# (4582, 1146)
